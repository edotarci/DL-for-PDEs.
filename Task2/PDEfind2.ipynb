# %% [markdown]
# # PDEfind for dataset 2

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from aux_for_PDE_find import*

torch.manual_seed(0)
np.random.seed(0)

# %% [markdown]
# ## Dataset preparation

# %%
path_train = "PDEfind_data/2.npz"
data_npz = np.load(path_train)

# Load the data from the .npz file
u = torch.from_numpy(data_npz['u']).type(torch.float32)  # Solution or field
u_plot = u
x = torch.from_numpy(data_npz['x']).type(torch.float32)  # Spatial variable
t = torch.from_numpy(data_npz['t']).type(torch.float32)  # Temporal variable

# %% [markdown]
# ## Build of $\Theta$

# %%
dt = t[0,1] - t[0,0]
dx = x[1,0] - x[0,0]

# Compute time derivative
dudt = compute_time_derivative(u, dt).reshape(-1, 1)

# Compute space derivatives
dudx = compute_space_derivative(u, dx, 1)
dudx_2 = compute_space_derivative(u, dx, 2)
dudx_3 = compute_space_derivative(u, dx, 3)

# Compute other terms
u2 = torch.pow(u, 2)
u3 = torch.pow(u, 3)  

# Compute mixed terms
u_times_dudx = torch.mul(u, dudx)
u2_times_dudx = torch.mul(u2, dudx)
u3_times_dudx = torch.mul(u3, dudx)

u_times_dudx_2 = torch.mul(u, dudx_2)
u2_times_dudx_2 = torch.mul(u2, dudx_2)
u3_times_dudx_2 = torch.mul(u3, dudx_2)

u_times_dudx_3 = torch.mul(u, dudx_3)
u2_times_dudx_3 = torch.mul(u2, dudx_3)
u3_times_dudx_3 = torch.mul(u3, dudx_3)

# Compute bias
bias = torch.ones_like(u)

# Reshape all terms
u = u.reshape(-1, 1)
x = x.reshape(-1, 1)
t = t.reshape(-1, 1)
dudx = dudx.reshape(-1, 1)
dudx_2 = dudx_2.reshape(-1, 1)
dudx_3 = dudx_3.reshape(-1, 1)
u2 = u2.reshape(-1, 1)
u3 = u3.reshape(-1, 1) 
u_times_dudx = u_times_dudx.reshape(-1, 1)
u2_times_dudx = u2_times_dudx.reshape(-1, 1)
u3_times_dudx = u3_times_dudx.reshape(-1, 1)  
u_times_dudx_2 = u_times_dudx_2.reshape(-1, 1)
u2_times_dudx_2 = u2_times_dudx_2.reshape(-1, 1)
u3_times_dudx_2 = u3_times_dudx_2.reshape(-1, 1)  
u_times_dudx_3 = u_times_dudx_3.reshape(-1, 1)
u2_times_dudx_3 = u2_times_dudx_3.reshape(-1, 1)
u3_times_dudx_3 = u3_times_dudx_3.reshape(-1, 1)  
bias = bias.reshape(-1, 1)

# Combine all vectors into a single matrix
Theta = torch.cat([
    bias,               # 0
    u,                  # 1
    t,                  # 2
    dudx,               # 3
    dudx_2,             # 4
    dudx_3,             # 5
    u2,                 # 6
    u3,                 # 7
    u_times_dudx,       # 8
    u2_times_dudx,      # 9
    u3_times_dudx,      # 10
    u_times_dudx_2,     # 11
    u2_times_dudx_2,    # 12
    u3_times_dudx_2,    # 13
    u_times_dudx_3,     # 14
    u2_times_dudx_3,    # 15
    u3_times_dudx_3     # 16
], dim=1)

# Update Theta names
Theta_names = [
    "bias",             # 0
    "u",                # 1
    "t",                # 2
    "dudx",             # 3
    "dudx_2",           # 4
    "dudx_3",           # 5
    "u2",               # 6
    "u3",               # 7
    "u_times_dudx",     # 8
    "u2_times_dudx",    # 9
    "u3_times_dudx",    # 10
    "u_times_dudx_2",   # 11
    "u2_times_dudx_2",  # 12
    "u3_times_dudx_2",  # 13
    "u_times_dudx_3",   # 14
    "u2_times_dudx_3",  # 15
    "u3_times_dudx_3"   # 16
]

# %% [markdown]
# ## Regression and printing of the PDE

# %% [markdown]
# #### using myregression

# %%
threshold=0.5
alpha = [0.1,0.01, 0.0]
selected_names, regression_coef_ = myregression(Theta,dudt,Theta_names,alpha=alpha,threshold=threshold,test_size=0.2)
# Out:
# Regression # 1
# dudx_3  c=  -0.6407503536292458
# u_times_dudx  c=  -3.3456804509339046
# u2_times_dudx  c=  -1.0782930459970195
# Mean Squared Error: 0.00037880212220270875
# ###################### end of regression 1 ##############################
#
# Regression # 2
# dudx_3  c=  -0.9685902693104561
# u_times_dudx  c=  -6.01422566538533
# Mean Squared Error: 8.617746196119369e-06
# ###################### end of regression 2 ##############################
#
# Regression # 3
# dudx_3  c=  -0.9951867395510569
# u_times_dudx  c=  -5.977750491806644
# Mean Squared Error: 5.299312677128333e-06
# ###################### end of regression 3 ##############################

# %%
printPDE(selected_names, regression_coef_)
# Out:
# dudt = -0.9951867395510569 * dudx_3 +
#        -5.977750491806644 * u_times_dudx

# %% [markdown]
# #### using myregression2

# %%
threshold=4
alpha = [0.1,0.01, 0.0]
selected_names, regression_coef_ = myregression2(Theta,dudt,Theta_names,alpha=alpha,threshold=threshold,test_size=0.2)
# Out:
# Regression # 1
# dudx  c=  -0.36643399876273863
# dudx_3  c=  -0.6407503536292458
# u_times_dudx  c=  -3.3456804509339046
# Mean Squared Error: 5.540403783556604e-05
# ###################### end of regression 1 ##############################
#
# Regression # 2
# dudx_3  c=  -0.8867152421367865
# u_times_dudx  c=  -5.342151849034042
# Mean Squared Error: 3.0649923665252205e-05
# ###################### end of regression 2 ##############################
#
# Regression # 3
# dudx_3  c=  -0.9951867395510569
# u_times_dudx  c=  -5.977750491806644
# Mean Squared Error: 5.299312677128333e-06
# ###################### end of regression 3 ##############################

# %%
printPDE(selected_names, regression_coef_)
# Out:
# dudt = -0.9951867395510569 * dudx_3 +
#        -5.977750491806644 * u_times_dudx

# %% [markdown]
# # Plot

# %%
space =  torch.arange(x[0,0], abs(x[0,0]), dx)

plt.figure(figsize=(8, 5))
for i in np.arange(0,200,20):
    plt.plot(space, u_plot[:, i],)
    

plt.xlabel("Spatial variable (x)")
plt.ylabel("Field (u)")
plt.title("Field Evolution Over Time")
plt.legend()
plt.grid()
# Out:
# /var/folders/2c/01bhfspx2hj56fb5ryg654lr0000gn/T/ipykernel_25364/3846645649.py:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
